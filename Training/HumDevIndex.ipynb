# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Development = pd.read_csv("../Dataset/h.csv.csv")
Development.head()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("../Dataset/h.csv.csv")
data.columns = data.columns.str.strip()

# First 20 rows
data1 = data.head(20)

# -----------------------------
# 1. Unique Countries
# -----------------------------
print("Unique Countries:")
print(data1["Country"].unique())

# -----------------------------
# 2. Choose correct HDI column (2021)
# -----------------------------
hdi_col = "Human Development Index (2021)"

# -----------------------------
# 3. Plot HDI trend (1990 vs 2021 style comparison)
# -----------------------------
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="HDI Rank (2021)",
    y=hdi_col,
    data=data1
)
plt.title("HDI Rank vs HDI (2021)")
plt.show()

# -----------------------------
# 4. Correlation Heatmap (ONLY numeric columns)
# -----------------------------
plt.figure(figsize=(12,6))

numeric_data = data1.select_dtypes(include=["number"])
sns.heatmap(numeric_data.corr(), annot=False, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %%
# Independent Variables
X = data.iloc[:, [4, 32, 33, 34]]
X = pd.DataFrame(X)

# Dependent Variable
y = data.iloc[:, 35]
y = pd.DataFrame(y)

# %%
# Show null values
print("Null values in X:")
print(X.isnull().sum())

# Fill only numeric columns with mean
X = X.apply(lambda col: col.fillna(col.mean()) if col.dtype != 'object' else col)
# Out:
# Null values in X:
# HDI Rank (2021)                   4
# Human Development Index (2017)    5
# Human Development Index (2018)    4
# Human Development Index (2019)    4
# dtype: int64

# %%
import pandas as pd

data = pd.read_csv("../Dataset/h.csv.csv")
data.columns = data.columns.str.strip()

# %%
# Independent Variables
X = data.iloc[:, [4, 32, 33, 34]]
X = pd.DataFrame(X)

# Dependent Variable
y = data.iloc[:, 35]
y = pd.DataFrame(y)

# %%
X = X.fillna(X.mean())
y = y.fillna(y.mean())

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.10,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (175, 4)
# (20, 4)

# %%
# Import Linear Regression model
from sklearn.linear_model import LinearRegression

# Create the Linear Regression model
model = LinearRegression()

# Train the model using the training dataset
model.fit(X_train, y_train)

print("Model trained successfully!")

# Predict the target values using the testing dataset
y_pred = model.predict(X_test)

# Display the first 5 predicted values
print("Predicted Values:")
print(y_pred[:5])
y_test
# Out:
# Model trained successfully!
# Predicted Values:
# [[0.70844917]
#  [0.80247956]
#  [0.47812728]
#  [0.60444827]
#  [0.88268798]]
#      Human Development Index (2020)
# 138                           0.710
# 16                            0.802
# 155                           0.475
# 96                            0.608
# 68                            0.886
# 153                           0.939
# 55                            0.498
# 15                            0.655
# 112                           0.756
# 111                           0.734
# 184                           0.920
# 18                            0.815
# 82                            0.957
# 9                             0.913
# 164                           0.913
# 117                           0.600
# 69                            0.792
# 113                           0.639
# 192                           0.727
# 119                           0.745
